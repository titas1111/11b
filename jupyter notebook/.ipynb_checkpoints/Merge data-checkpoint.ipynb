# %%
import pandas as pd
import os

# %%
path = os.getcwd()+"\\input"
files = os.listdir(path)

files_xls = [r"C:\Users\Titas\Desktop\11b\jupyter notebook\input\\"+f for f in files if f[-4:] == 'xlsx']
files_xls

df = pd.DataFrame()
for f in files_xls:
    data = pd.read_excel(f, 'Sheet1', sort=False)
    df = df.append(data)
# Out:
# 1147

# %%
df
# Out:
#                                               Adresas Aktyvus iki  \
# 0   https://www.aruodas.lt/butai-vilniuje-pasilaic...         NaN
# 1   https://www.aruodas.lt/butu-nuoma-vilniuje-nau...         NaN
# 2   https://www.aruodas.lt/butu-nuoma-vilniuje-sen...         NaN
# 3   https://www.aruodas.lt/butu-nuoma-vilniuje-laz...         NaN
# 4   https://www.aruodas.lt/butu-nuoma-vilniuje-pil...  2020-01-08
# ..                                                ...         ...
# 21  https://www.aruodas.lt/butu-nuoma-vilniuje-laz...  2019-12-29
# 22  https://www.aruodas.lt/butu-nuoma-vilniuje-san...  2019-12-29
# 23  https://www.aruodas.lt/butu-nuoma-vilniuje-fab...  2019-12-29
# 24  https://www.aruodas.lt/butu-nuoma-vilniuje-jus...         NaN
# 25  https://www.aruodas.lt/butu-nuoma-vilniuje-sen...  2019-12-29
#
#                                              Apsauga:  Aukštas:  Aukštų sk.:  \
# 0                                                 NaN       NaN          NaN
# 1                                                 NaN       4.0          6.0
# 2                                                 NaN       4.0          6.0
# 3             Šarvuotos durys\nKodinė laiptinės spyna       2.0          4.0
# 4   Šarvuotos durys\nSignalizacija\nKodinė laiptin...       1.0          4.0
# ..                                                ...       ...          ...
# 21                                                NaN       5.0          5.0
# 22            Šarvuotos durys\nKodinė laiptinės spyna       1.0          9.0
# 23                             Kodinė laiptinės spyna       3.0         10.0
# 24                                    Šarvuotos durys       8.0          9.0
# 25                                                NaN       3.0          4.0
#
#    Buto numeris: Kaina mėn.:  Kambarių sk.:                         Metai:  \
# 0            NaN         NaN            NaN                            NaN
# 1             24       890 €            3.0                           2017
# 2             24       890 €            3.0                           2017
# 3            NaN       440 €            2.0                           2008
# 4            NaN       460 €            2.0                           2007
# ..           ...         ...            ...                            ...
# 21           NaN       300 €            2.0                           1975
# 22           NaN       270 €            1.0  1984 statyba, 2017 renovacija
# 23           NaN       130 €            1.0                           1990
# 24           NaN       250 €            1.0                           1986
# 25           NaN       590 €            2.0                           2018
#
#    Namo numeris:  ... Pastato energijos suvartojimo klasė: Pastato tipas:  \
# 0            NaN  ...                                  NaN            NaN
# 1              4  ...                                  NaN    Monolitinis
# 2              4  ...                                  NaN    Monolitinis
# 3            NaN  ...                                  NaN        Mūrinis
# 4             13  ...                                  NaN        Mūrinis
# ..           ...  ...                                  ...            ...
# 21            72  ...                                  NaN       Blokinis
# 22             9  ...                                  NaN        Mūrinis
# 23            90  ...                                  NaN       Blokinis
# 24           231  ...                                  NaN       Blokinis
# 25            85  ...                                  NaN        Mūrinis
#
#                      Peržiūrėjo   Plotas:  Redaguotas  \
# 0                           NaN       NaN         NaN
# 1    3641/99 (iš viso/šiandien)     76 m²  2019-11-28
# 2     753/35 (iš viso/šiandien)     76 m²  2019-11-28
# 3    183/183 (iš viso/šiandien)     68 m²  2019-12-04
# 4   2138/124 (iš viso/šiandien)  56,63 m²  2019-11-27
# ..                          ...       ...         ...
# 21    528/36 (iš viso/šiandien)     49 m²  2019-12-04
# 22   1317/96 (iš viso/šiandien)     36 m²  2019-11-29
# 23   3233/55 (iš viso/šiandien)     15 m²  2019-11-24
# 24  5283/127 (iš viso/šiandien)     36 m²  2019-11-27
# 25  1043/101 (iš viso/šiandien)     46 m²  2019-12-04
#
#                                             Ypatybės:      Įdėtas  \
# 0                                                 NaN         NaN
# 1                                                 NaN  2019-11-11
# 2                                                 NaN  2019-11-28
# 3   Aukštos lubos\nNauja kanalizacija\nNauja elekt...  2019-12-04
# 4   Internetas\nKabelinė televizija\nVirtuvė sujun...  2019-11-24
# ..                                                ...         ...
# 21                                                NaN  2019-11-29
# 22  Internetas\nKabelinė televizija\nVirtuvė sujun...  2019-11-29
# 23             Tualetas ir vonia atskirai\nButo dalis  2019-11-14
# 24                         Tualetas ir vonia atskirai  2019-11-14
# 25  Atskiras įėjimas\nNauja elektros instaliacija\...  2019-11-29
#
#                                            Įrengimas: Įsiminė  \
# 0                                                 NaN     NaN
# 1   Įrengtas                                      ...     5.0
# 2   Įrengtas                                      ...     2.0
# 3   Įrengtas                                      ...     1.0
# 4   Įrengtas                                      ...     1.0
# ..                                                ...     ...
# 21  Įrengtas                                      ...     1.0
# 22  Įrengtas                                      ...     4.0
# 23  Įrengtas                                      ...     2.0
# 24  Įrengtas                                      ...    15.0
# 25  Įrengtas                                      ...    23.0
#
#                  Šildymas:
# 0                      NaN
# 1   Centrinis kolektorinis
# 2   Centrinis kolektorinis
# 3   Centrinis kolektorinis
# 4   Centrinis kolektorinis
# ..                     ...
# 21               Centrinis
# 22  Centrinis kolektorinis
# 23               Centrinis
# 24               Centrinis
# 25  Centrinis kolektorinis
#
# [1147 rows x 23 columns]

# %%
df.to_excel("output input all features.xlsx", index= False)
