# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from scipy.stats import uniform, truncnorm, randint
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('output_excluded_senamiestyje.csv')
df.describe()
# Out:
#              floor  total_floor_num   rent_price     room_num         area  \
# count  1610.000000      1609.000000  1611.000000  1609.000000  1611.000000
# mean      3.477019         6.204475   464.403476     1.992542    60.845481
# std       2.316430         3.264246   219.548608     0.926366   280.952099
# min       0.000000         1.000000    15.000000     1.000000     1.000000
# 25%       2.000000         4.000000   329.000000     1.000000    35.235000
# 50%       3.000000         5.000000   430.000000     2.000000    49.000000
# 75%       5.000000         9.000000   550.000000     2.000000    63.000000
# max      20.000000        29.000000  1480.000000    18.000000  8000.000000
#
#               year  year_renovation  floors_from_top    top_floor
# count  1611.000000        50.000000      1609.000000  1611.000000
# mean   1991.458101      2014.680000         2.725295     0.196151
# std      73.807505         4.537553         2.656376     0.397208
# min       0.000000      2001.000000         0.000000     0.000000
# 25%    1980.000000      2014.000000         1.000000     0.000000
# 50%    2002.000000      2016.000000         2.000000     0.000000
# 75%    2011.000000      2018.000000         4.000000     0.000000
# max    2019.000000      2019.000000        24.000000     1.000000

# %%
df.head()
# Out:
#                                              Adresas  floor  total_floor_num  \
# 0  https://www.aruodas.lt/butu-nuoma-vilniuje-pas...    3.0              9.0
# 1  https://www.aruodas.lt/butu-nuoma-vilniuje-zve...    4.0              4.0
# 2  https://www.aruodas.lt/butu-nuoma-vilniuje-zve...    2.0              3.0
# 3  https://www.aruodas.lt/butu-nuoma-vilniuje-laz...    2.0              5.0
# 4  https://www.aruodas.lt/butu-nuoma-vilniuje-laz...    2.0              5.0
#
#   Buto numeris:  rent_price  room_num year_full Namo numeris: Nuoroda  \
# 0           NaN         450       2.0      2007           NaN     NaN
# 1           NaN         699       2.0      2019            10     NaN
# 2           NaN         400       2.0      1969           NaN     NaN
# 3           NaN         390       1.0      2008           NaN     NaN
# 4           NaN         700       3.0      1998           NaN     NaN
#
#   Pastato tipas:  ...    area  Redaguotas Įdėtas  \
# 0        Mūrinis  ...   64.00         NaN    NaN
# 1        Mūrinis  ...   41.47         NaN    NaN
# 2        Mūrinis  ...   41.84         NaN    NaN
# 3        Mūrinis  ...   36.00         NaN    NaN
# 4        Mūrinis  ...  119.00         NaN    NaN
#
#                                           Įrengimas:               Šildymas:  \
# 0  Įrengtas                                      ...  Centrinis kolektorinis
# 1                                                NaN      Centrinis, elektra
# 2  Įrengtas                                      ...               Centrinis
# 3  Įrengtas                                      ...  Centrinis kolektorinis
# 4  Įrengtas                                      ...  Centrinis kolektorinis
#
#    year  year_renovation  floors_from_top  top_floor       district
# 0  2007              NaN              6.0          0  pasilaiciuose
# 1  2019              NaN              0.0          1        zveryne
# 2  1969              NaN              1.0          0        zveryne
# 3  2008              NaN              3.0          0  lazdyneliuose
# 4  1998              NaN              3.0          0     lazdynuose
#
# [5 rows x 21 columns]

# %% [markdown]
# ## encoder

# %%
# le = preprocessing.LabelEncoder()
# df["district"].fillna("None", inplace = True)
# df["district"] = le.fit_transform(df["district"])

# %%
# http://www.insightsbot.com/python-one-hot-encoding-with-scikit-learn/
df["district"].fillna("None", inplace = True)
district_ohe = OneHotEncoder()

X = district_ohe.fit_transform(df.district.values.reshape(-1,1)).toarray()
dfOneHot = pd.DataFrame(X, columns = ["district_"+str(int(i)) for i in range(X.shape[1])])
df = pd.concat([df, dfOneHot], axis=1)

# %% [markdown]
# ## pipline and model

# %%
Pipeline_rfr = Pipeline(steps = [
    ("impute", SimpleImputer(missing_values=np.nan)), 
    ("rfr", RandomForestRegressor(random_state=42))
])

# %% [markdown]
# ## train_test_split

# %%
df_train = df.select_dtypes(include=['float64','int64'])

df_features = df_train.drop(columns="rent_price")
df_target = df_train["rent_price"]

X_train, X_test, y_train, y_test = train_test_split(df_features, df_target, random_state=42)

# %%
# https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'rfr__n_estimators': n_estimators,
               'rfr__max_features': max_features,
               'rfr__max_depth': max_depth,
               'rfr__min_samples_split': min_samples_split,
               'rfr__min_samples_leaf': min_samples_leaf,
               'rfr__bootstrap': bootstrap}

rf_random = RandomizedSearchCV(Pipeline_rfr, param_distributions = random_grid, cv = 5, scoring="neg_mean_squared_error", n_iter=100)

# %%
rf_random.fit(X_train, y_train)
print(rf_random.best_estimator_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-cf098c8abecb> in <module>
# ----> 1 rf_random.fit(X_train, y_train)
#       2 print(rf_random.best_estimator_)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1467         evaluate_candidates(ParameterSampler(
#    1468             self.param_distributions, self.n_iter,
# -> 1469             random_state=self.random_state))
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     354                                  self._log_message(len(self.steps) - 1)):
#     355             if self._final_estimator != 'passthrough':
# --> 356                 self._final_estimator.fit(Xt, y, **fit_params)
#     357         return self
#     358
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     315             trees = [self._make_estimator(append=False,
#     316                                           random_state=random_state)
# --> 317                      for i in range(n_more_estimators)]
#     318
#     319             # Parallel loop: we prefer the threading backend as the Cython code
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in <listcomp>(.0)
#     315             trees = [self._make_estimator(append=False,
#     316                                           random_state=random_state)
# --> 317                      for i in range(n_more_estimators)]
#     318
#     319             # Parallel loop: we prefer the threading backend as the Cython code
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\base.py in _make_estimator(self, append, random_state)
#     129
#     130         if random_state is not None:
# --> 131             _set_random_states(estimator, random_state)
#     132
#     133         if append:
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\base.py in _set_random_states(estimator, random_state)
#      55
#      56     if to_set:
# ---> 57         estimator.set_params(**to_set)
#      58
#      59
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in set_params(self, **params)
#     213             # Simple optimization to gain speed (inspect is slow)
#     214             return self
# --> 215         valid_params = self.get_params(deep=True)
#     216
#     217         nested_params = defaultdict(dict)  # grouped by prefix
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     190         """
#     191         out = dict()
# --> 192         for key in self._get_param_names():
#     193             value = getattr(self, key, None)
#     194             if deep and hasattr(value, 'get_params'):
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _get_param_names(cls)
#     162         init_signature = inspect.signature(init)
#     163         # Consider the constructor parameters excluding 'self'
# --> 164         parameters = [p for p in init_signature.parameters.values()
#     165                       if p.name != 'self' and p.kind != p.VAR_KEYWORD]
#     166         for p in parameters:
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in <listcomp>(.0)
#     163         # Consider the constructor parameters excluding 'self'
#     164         parameters = [p for p in init_signature.parameters.values()
# --> 165                       if p.name != 'self' and p.kind != p.VAR_KEYWORD]
#     166         for p in parameters:
#     167             if p.kind == p.VAR_POSITIONAL:
#
# ~\Anaconda3\lib\inspect.py in kind(self)
#    2529     @property
#    2530     def kind(self):
# -> 2531         return self._kind
#    2532
#    2533     def replace(self, *, name=_void, kind=_void,
#
# KeyboardInterrupt:

# %%
print("RSME:", int((mean_squared_error(y_test, rf_random.predict(X_test)))**0.5))
# Out:
# RSME: 98

# %%
print("RSME:", int((mean_squared_error(y_train, rf_random.predict(X_train)))**0.5))
# Out:
# RSME: 40

# %% [markdown]
# ## Gradient Boosting regression

# %%
# Pipeline_gbrt = Pipeline(steps = [
#     ("impute", SimpleImputer(missing_values=np.nan)), 
#     ("gbrt", GradientBoostingRegressor(random_state=42))
# ])

# %%
# Pipeline_gbrt = Pipeline(steps = [
#     ("impute", SimpleImputer(missing_values=np.nan)), 
#     ("gbrt", GradientBoostingRegressor(random_state=42))
# ])

# params = {}

# gbrt_random = RandomizedSearchCV(Pipeline_gbrt,param_distributions = params, random_state=42)
# gbrt_random.fit(X_train, y_train)
# print("RSME:", int((mean_squared_error(y_test, gbrt_random.predict(X_test)))**0.5))

# %%
# print("RSME:", int((mean_squared_error(y_train, gbrt_random.predict(X_train)))**0.5))

# %% [markdown]
# ## export

# %%
import joblib
# joblib.dump(rf_random, 'my_model_excluded_senamiestyje.pkl', compress=9)
model_clone = joblib.load('my_model_excluded_senamiestyje.pkl')

# %% [markdown]
# ## feature_importances

# %%
feature_importances = model_clone.best_estimator_.named_steps['rfr'].feature_importances_
model = model_clone.best_estimator_.named_steps['rfr']
feature_names = X_train.columns

# %%
for importances, names in zip(feature_importances, feature_names):
    print(names, importances)
# Out:
# floor 0.04407009912029021
# total_floor_num 0.05128753840901065
# room_num 0.1638635671258875
# area 0.33280292422440966
# year 0.18706144219131252
# year_renovation 0.010902497833878859
# floors_from_top 0.03188398650091704
# top_floor 0.00895726740357749
# district_0 0.0027055679719479326
# district_1 0.007170601433815839
# district_2 5.6685242327655064e-05
# district_3 0.0029841185968190334
# district_4 0.0015683781658954001
# district_5 0.00016986474683025618
# district_6 0.00388717011105483
# district_7 0.00036363094243597766
# district_8 0.003013032746080555
# district_9 0.0006127036022129671
# district_10 0.00048405376347218984
# district_11 0.0011319803871552036
# district_12 0.0035630733538246184
# district_13 0.0002339238046712222
# district_14 0.002483066815783668
# district_15 0.0008092792148871994
# district_16 0.0031007947562752343
# district_17 0.0008529865241787478
# district_18 0.03542451866143863
# district_19 0.002440085318951727
# district_20 0.004267789517637558
# district_21 0.008248974704125688
# district_22 0.0010740548806149508
# district_23 0.005109921602603633
# district_24 0.0021816679913223952
# district_25 0.007097340237633045
# district_26 0.0013495686537586813
# district_27 0.010162949767893935
# district_28 0.0003585130694764954
# district_29 0.031936704484105814
# district_30 0.005358563352080954
# district_31 9.064165069896265e-05
# district_32 0.00032287347119446886
# district_33 0.00033355104354748053
# district_34 0.0012789099530185195
# district_35 0.002810864659208458
# district_36 0.014132271991736386

# %%
i = 0
for district in district_ohe.get_feature_names():
    print(district, i)
    i += 1
# Out:
# x0_None 0
# x0_antakalnyje 1
# x0_aukstuosiuose-paneriuose 2
# x0_avizieniuose 3
# x0_bajoruose 4
# x0_balsiuose 5
# x0_baltupiuose 6
# x0_burbiskes 7
# x0_fabijoniskese 8
# x0_filaretuose 9
# x0_grigiskese 10
# x0_jeruzaleje 11
# x0_justiniskese 12
# x0_kalnenuose 13
# x0_karoliniskese 14
# x0_lazdyneliuose 15
# x0_lazdynuose 16
# x0_markuciuose 17
# x0_naujamiestyje 18
# x0_naujininkuose 19
# x0_naujojoje-vilnioje 20
# x0_pasilaiciuose 21
# x0_pavilnyje 22
# x0_pilaiteje 23
# x0_santariskese 24
# x0_seskineje 25
# x0_siaures-miestelyje 26
# x0_snipiskese 27
# x0_tarandeje 28
# x0_uzupyje 29
# x0_valakampiuose 30
# x0_vilkpedeje 31
# x0_virsuliskese 32
# x0_visoriuose 33
# x0_zemuosiuose-paneriuose 34
# x0_zirmunuose 35
# x0_zveryne 36
